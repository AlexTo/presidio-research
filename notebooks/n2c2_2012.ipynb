# %%
from bs4 import BeautifulSoup
from tqdm import tqdm
import os
import spacy
import numpy as np
from presidio_evaluator.data_objects import InputSample, Span
import json

# %%
nlp = spacy.load("en_core_web_trf", disable=["ner"])

# %%
dir = '/data/datasets/n2c2/2012/raw/train/'

# %%
xmls = []
for file_name in tqdm(os.listdir(dir)):
    if not file_name.endswith(".xml") or "_" in file_name:
        print(file_name)
        continue
    with open(os.path.join(dir, file_name), encoding='utf-8') as f:
        xmls.append({"file_name": file_name,
                     "content": BeautifulSoup(f.read(), features="xml")})

# %%
nlp.pipe_names
# Out:
# ['transformer', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer']

# %%
docs = []
processed = []
i = 0
with tqdm(xmls) as pbar:
    for xml in pbar:
        i += 1

        doc = nlp(xml["content"].ClinicalNarrativeTemporalAnnotation.TEXT.text)
        docs.append(doc)
        processed.append(i)
        pbar.update(1)
            
processed = np.array(processed)
processed = processed - 1
# Out:
# 100%|██████████| 190/190 [00:59<00:00,  3.22it/s]

# %% [markdown]
# Generate spans

# %%
input_samples = []

for i, ind in enumerate(tqdm(processed)):
    doc = docs[i]
    xml = xmls[ind]
    spans = [Span(entity_type=tag["type"],
                  entity_value=tag["text"],
                  start_position=int(tag["start"]),
                  end_position=int(tag["start"]) + len(tag["text"]))
             for tag in xml["content"].TAGS if tag.name == "EVENT"]
    
    input_sample = InputSample(doc.text, masked=None, spans=spans, create_tags_from_span = True, scheme="BILOU")
    input_samples.append(input_sample)
# Out:
#   0%|          | 0/190 [00:00<?, ?it/s]
# loading model en_core_web_trf
# 100%|██████████| 190/190 [01:01<00:00,  3.08it/s]

# %%
input_samples = [input_sample.to_dict() for input_sample in input_samples]

# %%
with open('/data/datasets/n2c2/2012/processed/test.json', 'w+', encoding="utf-8") as f:
    json.dump(input_samples, f)

# %%
input_samples[0]
# Out:
# {'full_text': "\nAdmission Date :\n2019-01-19\nDischarge Date :\n2019-01-24\nService : MEDICINE\nAllergies :\nHistory of Present Illness :\nThis is a 37 y/o male patient with PMH Type I DM , HTN , gastroparesis , ESRD on HD ( last in 12/26 per patient ) who presents to CMED CCU with hypertensive urgency unable from the Larry .\nThe patient early this morning to the Ruthie with his usual nausea , vomiting , abdominal pain and was found to be hypertensive to 256/110 , HR 102 , T 99.2 , RR 22 , 92% RA .\nHistory is difficult to obtain from patient d/t somnolence and lack of desire to participate in interview , but per Frank note he was diaphoretic and ' writing in pain ', vomiting clear substance .\nHe was given ativan a total of 4 mg of ativan , 6 mg of dilaudid , labetolol 20 mg IV x 1 and hydralazine 10 mg IV x 1 without good response ( 200/99 ).\nHe recieved 2L NS and was started on labetolol gtt and BP decreased to 161/79 .\nTranferred to CMED CCU for further management while on labetolol gtt .\nOf note , the patient is admitted to hospital 3 times every month for similar complaints with last admission 1/20-2/1/07 .\nAt that time BP was attributed to abdominal pain and inability to take PO meds d/t nausea / vomiting .\nAlso had labile blood sugars with repeated episodes of hypoglycemia , and Strickland recommended sugars in the range of 150-200 .\nHe eloped prior to formal discharge when his FS was found to be critically high - recommended to patient that he stay for repeat , but left AMA without signing any forms .\nUpon transfer to the CMED CCU the patient appears somewhat uncomfortable , reporting nausea and abdominal pain , but when questioned he was unable / unwilling to participate in HPI or exam d/t sleepiness .\nHe denied CP , SOB , HA , vision changes , neck stiffness , dysuria , or other symptoms .\nIn the CMED CCU he became hypotensive to SBP 80 s.\nLabetalol was stopped and he received a 500 cc fluid bolus and his blood pressure rose to SBP 90 s.\nCardiac and infectious sources of hypotension were considered , but cardiac enzymes were not changed from prior studies and he had no localizing signs of infection ; blood cultures were sent and a ultrasound of the L arm AVF ordered to rule out abscess at the site .\nHe received a partial HD session , limited by hypotension .\nOver night , his blood pressure trended up to 130 s systolic .\nHe was restarted on his home blood pressure regimen .\nRenal consult team saw him 2019-01-20 and plan to next dialyze him on 2019-01-21 .\nHe was to be called out to the medical floor on 2019-01-20 but became somnolent after receiving pain and anti-nausea meds , so he stayed in the ICU for closer monitoring of respiratory status , which spontaneously improved .\nHis blood sugar at 10 pm was low at 22 and he was disoriented , which resolved with two glasses of juice ; he did not receive his standing dose of NPH that evening .\nBlood cultures returned positive with GPC in pairs and clusters , so a TTE and surveillance cultures were ordered and vancomycin was started .\nHe was then called out to the medical floor on 01-21 .\nBrief Hospital Course :\nPt admitted to medical floor in hemodynamically stable condition without specific complaints .\n# hypertensive urgency :\nUpon presentation it was unclear when last time was that patient took meds , but hypertension likely d/t inability to take meds in setting of N/V .\nAlso contribution of autonomic dysfunction .\nNo evidence of active end organ damage .\nPt was treated with labetalol gtt in CMED CCU which was weaned off on 01-20 .\ncarduac enzymes mildly elevated , felt 02-08 demand ischemia in setting of hypertensive urgency , CK and MB trended Mcewen at time of admission to medical floor .\nPt 's hypertensive urgency was resolved upon admission to the medical floor .\nHis SBP s ranged 140 s- 170 s .\nHe was restarted on his home regimen of antihypertensives without difficulty ( metoprolol 75 tid , clonidine patch and oral , nifedipine 30  ...
#  'masked': None,
#  'spans': [{'entity_type': 'OCCURRENCE',
#    'entity_value': 'Admission',
#    'start_position': 1,
#    'end_position': 10},
#   {'entity_type': 'OCCURRENCE',
#    'entity_value': 'admitted',
#    'start_position': 1009,
#    'end_position': 1017},
#   {'entity_type': 'CLINICAL_DEPT',
#    'entity_value': 'hospital',
#    'start_position': 1021,
#    'end_position': 1029},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'similar complaints',
#    'start_position': 1054,
#    'end_position': 1072},
#   {'entity_type': 'OCCURRENCE',
#    'entity_value': 'last admission',
#    'start_position': 1078,
#    'end_position': 1092},
#   {'entity_type': 'TEST',
#    'entity_value': 'BP',
#    'start_position': 1120,
#    'end_position': 1122},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'abdominal pain',
#    'start_position': 1141,
#    'end_position': 1155},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'PO meds',
#    'start_position': 1178,
#    'end_position': 1185},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'nausea',
#    'start_position': 1190,
#    'end_position': 1196},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'vomiting',
#    'start_position': 1199,
#    'end_position': 1207},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'labile blood sugars',
#    'start_position': 1219,
#    'end_position': 1238},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'hypoglycemia',
#    'start_position': 1265,
#    'end_position': 1277},
#   {'entity_type': 'OCCURRENCE',
#    'entity_value': 'eloped',
#    'start_position': 1343,
#    'end_position': 1349},
#   {'entity_type': 'OCCURRENCE',
#    'entity_value': 'formal discharge',
#    'start_position': 1359,
#    'end_position': 1375},
#   {'entity_type': 'TEST',
#    'entity_value': 'his FS',
#    'start_position': 1381,
#    'end_position': 1387},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'critically high',
#    'start_position': 1404,
#    'end_position': 1419},
#   {'entity_type': 'OCCURRENCE',
#    'entity_value': 'stay',
#    'start_position': 1453,
#    'end_position': 1457},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'repeat',
#    'start_position': 1462,
#    'end_position': 1468},
#   {'entity_type': 'OCCURRENCE',
#    'entity_value': 'left AMA',
#    'start_position': 1475,
#    'end_position': 1483},
#   {'entity_type': 'OCCURRENCE',
#    'entity_value': 'signing',
#    'start_position': 1492,
#    'end_position': 1499},
#   {'entity_type': 'OCCURRENCE',
#    'entity_value': 'transfer',
#    'start_position': 1517,
#    'end_position': 1525},
#   {'entity_type': 'CLINICAL_DEPT',
#    'entity_value': 'the CMED CCU',
#    'start_position': 1529,
#    'end_position': 1541},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'Type I DM',
#    'start_position': 156,
#    'end_position': 165},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'somewhat uncomfortable',
#    'start_position': 1562,
#    'end_position': 1584},
#   {'entity_type': 'EVIDENTIAL',
#    'entity_value': 'reporting',
#    'start_position': 1587,
#    'end_position': 1596},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'nausea',
#    'start_position': 1597,
#    'end_position': 1603},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'abdominal pain',
#    'start_position': 1608,
#    'end_position': 1622},
#   {'entity_type': 'OCCURRENCE',
#    'entity_value': 'questioned',
#    'start_position': 1634,
#    'end_position': 1644},
#   {'entity_type': 'OCCURRENCE',
#    'entity_value': 'unable / unwilling to participate',
#    'start_position': 1652,
#    'end_position': 1685},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'HTN',
#    'start_position': 168,
#    'end_position': 171},
#   {'entity_type': 'OCCURRENCE',
#    'entity_value': 'HPI',
#    'start_position': 1689,
#    'end_position': 1692},
#   {'entity_type': 'TEST',
#    'entity_value': 'exam',
#    'start_position': 1696,
#    'end_position': 1700},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'sleepiness',
#    'start_position': 1705,
#    'end_position': 1715},
#   {'entity_type': 'EVIDENTIAL',
#    'entity_value': 'denied',
#    'start_position': 1721,
#    'end_position': 1727},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'CP',
#    'start_position': 1728,
#    'end_position': 1730},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'gastroparesis',
#    'start_position': 174,
#    'end_position': 187},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'SOB',
#    'start_position': 1733,
#    'end_position': 1736},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'HA',
#    'start_position': 1739,
#    'end_position': 1741},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'vision changes',
#    'start_position': 1744,
#    'end_position': 1758},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'neck stiffness',
#    'start_position': 1761,
#    'end_position': 1775},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'dysuria',
#    'start_position': 1778,
#    'end_position': 1785},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'other symptoms',
#    'start_position': 1791,
#    'end_position': 1805},
#   {'entity_type': 'CLINICAL_DEPT',
#    'entity_value': 'the CMED CCU',
#    'start_position': 1811,
#    'end_position': 1823},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'hypotensive',
#    'start_position': 1834,
#    'end_position': 1845},
#   {'entity_type': 'TEST',
#    'entity_value': 'SBP',
#    'start_position': 1849,
#    'end_position': 1852},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'Labetalol',
#    'start_position': 1859,
#    'end_position': 1868},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'ESRD',
#    'start_position': 190,
#    'end_position': 194},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'a 500 cc fluid bolus',
#    'start_position': 1897,
#    'end_position': 1917},
#   {'entity_type': 'TEST',
#    'entity_value': 'his blood pressure',
#    'start_position': 1922,
#    'end_position': 1940},
#   {'entity_type': 'OCCURRENCE',
#    'entity_value': 'rose',
#    'start_position': 1941,
#    'end_position': 1945},
#   {'entity_type': 'TEST',
#    'entity_value': 'SBP',
#    'start_position': 1949,
#    'end_position': 1952},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'HD',
#    'start_position': 198,
#    'end_position': 200},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'hypotension',
#    'start_position': 1993,
#    'end_position': 2004},
#   {'entity_type': 'TEST',
#    'entity_value': 'cardiac enzymes',
#    'start_position': 2027,
#    'end_position': 2042},
#   {'entity_type': 'OCCURRENCE',
#    'entity_value': 'changed',
#    'start_position': 2052,
#    'end_position': 2059},
#   {'entity_type': 'TEST',
#    'entity_value': 'prior studies',
#    'start_position': 2065,
#    'end_position': 2078},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'localizing signs of infection',
#    'start_position': 2093,
#    'end_position': 2122},
#   {'entity_type': 'TEST',
#    'entity_value': 'blood cultures',
#    'start_position': 2125,
#    'end_position': 2139},
#   {'entity_type': 'TEST',
#    'entity_value': 'a ultrasound',
#    'start_position': 2154,
#    'end_position': 2166},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'the L arm AVF',
#    'start_position': 2170,
#    'end_position': 2183},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'abscess at the site',
#    'start_position': 2204,
#    'end_position': 2223},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'a partial HD session',
#    'start_position': 2238,
#    'end_position': 2258},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'hypotension',
#    'start_position': 2272,
#    'end_position': 2283},
#   {'entity_type': 'TEST',
#    'entity_value': 'his blood pressure',
#    'start_position': 2299,
#    'end_position': 2317},
#   {'entity_type': 'OCCURRENCE',
#    'entity_value': 'trended up',
#    'start_position': 2318,
#    'end_position': 2328},
#   {'entity_type': 'OCCURRENCE',
#    'entity_value': 'presents',
#    'start_position': 235,
#    'end_position': 243},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'his home blood pressure regimen',
#    'start_position': 2369,
#    'end_position': 2400},
#   {'entity_type': 'CLINICAL_DEPT',
#    'entity_value': 'Renal consult team',
#    'start_position': 2403,
#    'end_position': 2421},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'dialyze',
#    'start_position': 2458,
#    'end_position': 2465},
#   {'entity_type': 'CLINICAL_DEPT',
#    'entity_value': 'CMED CCU',
#    'start_position': 247,
#    'end_position': 255},
#   {'entity_type': 'CLINICAL_DEPT',
#    'entity_value': 'the medical floor',
#    'start_position': 2513,
#    'end_position': 2530},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'somnolent',
#    'start_position': 2556,
#    'end_position': 2565},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'pain and anti-nausea meds',
#    'start_position': 2582,
#    'end_position': 2607},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'hypertensive urgency',
#    'start_position': 261,
#    'end_position': 281},
#   {'entity_type': 'CLINICAL_DEPT',
#    'entity_value': 'the ICU',
#    'start_position': 2626,
#    'end_position': 2633},
#   {'entity_type': 'TEST',
#    'entity_value': 'monitoring',
#    'start_position': 2645,
#    'end_position': 2655},
#   {'entity_type': 'TEST',
#    'entity_value': 'respiratory status',
#    'start_position': 2659,
#    'end_position': 2677},
#   {'entity_type': 'OCCURRENCE',
#    'entity_value': 'improved',
#    'start_position': 2700,
#    'end_position': 2708},
#   {'entity_type': 'TEST',
#    'entity_value': 'His blood sugar',
#    'start_position': 2711,
#    'end_position': 2726},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'low',
#    'start_position': 2740,
#    'end_position': 2743},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'disoriented',
#    'start_position': 2761,
#    'end_position': 2772},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'two glasses of juice',
#    'start_position': 2795,
#    'end_position': 2815},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'NPH',
#    'start_position': 2858,
#    'end_position': 2861},
#   {'entity_type': 'TEST',
#    'entity_value': 'Blood cultures',
#    'start_position': 2877,
#    'end_position': 2891},
#   {'entity_type': 'OCCURRENCE',
#    'entity_value': 'Discharge',
#    'start_position': 29,
#    'end_position': 38},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'GPC in pairs and clusters',
#    'start_position': 2915,
#    'end_position': 2940},
#   {'entity_type': 'CLINICAL_DEPT',
#    'entity_value': 'the Larry',
#    'start_position': 294,
#    'end_position': 303},
#   {'entity_type': 'TEST',
#    'entity_value': 'a TTE',
#    'start_position': 2946,
#    'end_position': 2951},
#   {'entity_type': 'TEST',
#    'entity_value': 'surveillance cultures',
#    'start_position': 2956,
#    'end_position': 2977},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'vancomycin',
#    'start_position': 2995,
#    'end_position': 3005},
#   {'entity_type': 'CLINICAL_DEPT',
#    'entity_value': 'the medical floor',
#    'start_position': 3046,
#    'end_position': 3063},
#   {'entity_type': 'OCCURRENCE',
#    'entity_value': 'admitted',
#    'start_position': 3102,
#    'end_position': 3110},
#   {'entity_type': 'CLINICAL_DEPT',
#    'entity_value': 'medical floor',
#    'start_position': 3114,
#    'end_position': 3127},
#   {'entity_type': 'OCCURRENCE',
#    'entity_value': 'hemodynamically stable condition',
#    'start_position': 3131,
#    'end_position': 3163},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'specific complaints',
#    'start_position': 3172,
#    'end_position': 3191},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'hypertensive urgency',
#    'start_position': 3196,
#    'end_position': 3216},
#   {'entity_type': 'OCCURRENCE',
#    'entity_value': 'presentation',
#    'start_position': 3224,
#    'end_position': 3236},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'meds',
#    'start_position': 3289,
#    'end_position': 3293},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'hypertension',
#    'start_position': 3300,
#    'end_position': 3312},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'inability to take meds',
#    'start_position': 3324,
#    'end_position': 3346},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'N/V',
#    'start_position': 3361,
#    'end_position': 3364},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'autonomic dysfunction',
#    'start_position': 3388,
#    'end_position': 3409},
#   {'entity_type': 'CLINICAL_DEPT',
#    'entity_value': 'the Ruthie',
#    'start_position': 340,
#    'end_position': 350},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'active end organ damage',
#    'start_position': 3427,
#    'end_position': 3450},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'labetalol gtt',
#    'start_position': 3473,
#    'end_position': 3486},
#   {'entity_type': 'CLINICAL_DEPT',
#    'entity_value': 'CMED CCU',
#    'start_position': 3490,
#    'end_position': 3498},
#   {'entity_type': 'TEST',
#    'entity_value': 'carduac enzymes',
#    'start_position': 3531,
#    'end_position': 3546},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'mildly elevated',
#    'start_position': 3547,
#    'end_position': 3562},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'his usual nausea',
#    'start_position': 356,
#    'end_position': 372},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'demand ischemia',
#    'start_position': 3576,
#    'end_position': 3591},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'hypertensive urgency',
#    'start_position': 3606,
#    'end_position': 3626},
#   {'entity_type': 'TEST',
#    'entity_value': 'CK',
#    'start_position': 3629,
#    'end_position': 3631},
#   {'entity_type': 'TEST',
#    'entity_value': 'MB',
#    'start_position': 3636,
#    'end_position': 3638},
#   {'entity_type': 'OCCURRENCE',
#    'entity_value': 'admission',
#    'start_position': 3665,
#    'end_position': 3674},
#   {'entity_type': 'CLINICAL_DEPT',
#    'entity_value': 'medical floor',
#    'start_position': 3678,
#    'end_position': 3691},
#   {'entity_type': 'PROBLEM',
#    'entity_value': "Pt 's hypertensive urgency",
#    'start_position': 3694,
#    'end_position': 3720},
#   {'entity_type': 'OCCURRENCE',
#    'entity_value': 'admission',
#    'start_position': 3739,
#    'end_position': 3748},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'vomiting',
#    'start_position': 375,
#    'end_position': 383},
#   {'entity_type': 'CLINICAL_DEPT',
#    'entity_value': 'the medical floor',
#    'start_position': 3752,
#    'end_position': 3769},
#   {'entity_type': 'TEST',
#    'entity_value': 'His SBP s',
#    'start_position': 3772,
#    'end_position': 3781},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'antihypertensives',
#    'start_position': 3844,
#    'end_position': 3861},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'abdominal pain',
#    'start_position': 386,
#    'end_position': 400},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'difficulty',
#    'start_position': 3870,
#    'end_position': 3880},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'metoprolol',
#    'start_position': 3883,
#    'end_position': 3893},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'clonidine patch and oral',
#    'start_position': 3903,
#    'end_position': 3927},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'nifedipine',
#    'start_position': 3930,
#    'end_position': 3940},
#   {'entity_type': 'OCCURRENCE',
#    'entity_value': 'discharged',
#    'start_position': 3965,
#    'end_position': 3975},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'bacteremia',
#    'start_position': 4012,
#    'end_position': 4022},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'coag neg staph',
#    'start_position': 4045,
#    'end_position': 4059},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'PORT',
#    'start_position': 4090,
#    'end_position': 4094},
#   {'entity_type': 'PROBLEM',
#    'entity_value': '+ blood cultures',
#    'start_position': 4159,
#    'end_position': 4175},
#   {'entity_type': 'TEST',
#    'entity_value': 'TTE',
#    'start_position': 4198,
#    'end_position': 4201},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'hypertensive',
#    'start_position': 421,
#    'end_position': 433},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'endocarditis',
#    'start_position': 4244,
#    'end_position': 4256},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'stigmata of SBE',
#    'start_position': 4270,
#    'end_position': 4285},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'removal of PORT',
#    'start_position': 4326,
#    'end_position': 4341},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'vancomycin',
#    'start_position': 4412,
#    'end_position': 4422},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'hemodialysis',
#    'start_position': 4426,
#    'end_position': 4438},
#   {'entity_type': 'TEST',
#    'entity_value': 'HR',
#    'start_position': 447,
#    'end_position': 449},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'A PICC',
#    'start_position': 4484,
#    'end_position': 4490},
#   {'entity_type': 'TEST',
#    'entity_value': 'T',
#    'start_position': 456,
#    'end_position': 457},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'PORT',
#    'start_position': 4577,
#    'end_position': 4581},
#   {'entity_type': 'TEST',
#    'entity_value': 'RR',
#    'start_position': 465,
#    'end_position': 467},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'PORT',
#    'start_position': 4644,
#    'end_position': 4648},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'diabetic gastropathy',
#    'start_position': 4716,
#    'end_position': 4736},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'inability to toleral oral antihypertensive medication',
#    'start_position': 4745,
#    'end_position': 4798},
#   {'entity_type': 'OCCURRENCE',
#    'entity_value': 'repeated Donald presentation',
#    'start_position': 4809,
#    'end_position': 4837},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'hypertensive urgency',
#    'start_position': 4842,
#    'end_position': 4862},
#   {'entity_type': 'TEST',
#    'entity_value': 'surveillance cultures',
#    'start_position': 4873,
#    'end_position': 4894},
#   {'entity_type': 'TEST',
#    'entity_value': 'port tip cultures',
#    'start_position': 4899,
#    'end_position': 4916},
#   {'entity_type': 'EVIDENTIAL',
#    'entity_value': 'showing',
#    'start_position': 4917,
#    'end_position': 4924},
#   {'entity_type': 'TEST',
#    'entity_value': 'futher surveillance cultures',
#    'start_position': 4954,
#    'end_position': 4982},
#   {'entity_type': 'CLINICAL_DEPT',
#    'entity_value': 'hemodialysis',
#    'start_position': 4992,
#    'end_position': 5004},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'n/v/',
#    'start_position': 5042,
#    'end_position': 5046},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'abdominal pain',
#    'start_position': 5047,
#    'end_position': 5061},
#   {'entity_type': 'OCCURRENCE',
#    'entity_value': 'admissions',
#    'start_position': 5081,
#    'end_position': 5091},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'similar complaints',
#    'start_position': 5097,
#    'end_position': 5115},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'gastroparesis',
#    'start_position': 5133,
#    'end_position': 5146},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'ativan',
#    'start_position': 5176,
#    'end_position': 5182},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'dilaudid',
#    'start_position': 5185,
#    'end_position': 5193},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'reglan',
#    'start_position': 5196,
#    'end_position': 5202},
#   {'entity_type': 'OCCURRENCE',
#    'entity_value': 'tolerating',
#    'start_position': 5212,
#    'end_position': 5222},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'PO meds',
#    'start_position': 5223,
#    'end_position': 5230},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'diet',
#    'start_position': 5233,
#    'end_position': 5237},
#   {'entity_type': 'OCCURRENCE',
#    'entity_value': 'admission',
#    'start_position': 5249,
#    'end_position': 5258},
#   {'entity_type': 'CLINICAL_DEPT',
#    'entity_value': 'medical service',
#    'start_position': 5262,
#    'end_position': 5277},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'somnolence',
#    'start_position': 530,
#    'end_position': 540},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'oral reglan',
#    'start_position': 5299,
#    'end_position': 5310},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'DMI',
#    'start_position': 5315,
#    'end_position': 5318},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'sliding scale',
#    'start_position': 5327,
#    'end_position': 5340},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'NPH',
#    'start_position': 5365,
#    'end_position': 5368},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'hypoglycemia',
#    'start_position': 5415,
#    'end_position': 5427},
#   {'entity_type': 'TEST',
#    'entity_value': 'FSBS',
#    'start_position': 5430,
#    'end_position': 5434},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'lack of desire',
#    'start_position': 545,
#    'end_position': 559},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'current insulin regimen',
#    'start_position': 5523,
#    'end_position': 5546},
#   {'entity_type': 'OCCURRENCE',
#    'entity_value': 'discharge',
#    'start_position': 5554,
#    'end_position': 5563},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'NPH',
#    'start_position': 5597,
#    'end_position': 5600},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'CAD',
#    'start_position': 5642,
#    'end_position': 5645},
#   {'entity_type': 'EVIDENTIAL',
#    'entity_value': 'denied',
#    'start_position': 5651,
#    'end_position': 5657},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'cp',
#    'start_position': 5658,
#    'end_position': 5660},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'sob',
#    'start_position': 5663,
#    'end_position': 5666},
#   {'entity_type': 'OCCURRENCE',
#    'entity_value': 'hospitalization',
#    'start_position': 5678,
#    'end_position': 5693},
#   {'entity_type': 'TEST',
#    'entity_value': 'Troponins',
#    'start_position': 5696,
#    'end_position': 5705},
#   {'entity_type': 'OCCURRENCE',
#    'entity_value': 'rose',
#    'start_position': 5706,
#    'end_position': 5710},
#   {'entity_type': 'OCCURRENCE',
#    'entity_value': 'admission',
#    'start_position': 5714,
#    'end_position': 5723},
#   {'entity_type': 'TEST',
#    'entity_value': 'CK',
#    'start_position': 5734,
#    'end_position': 5736},
#   {'entity_type': 'TEST',
#    'entity_value': 'MB',
#    'start_position': 5741,
#    'end_position': 5743},
#   {'entity_type': 'OCCURRENCE',
#    'entity_value': 'admission',
#    'start_position': 5772,
#    'end_position': 5781},
#   {'entity_type': 'CLINICAL_DEPT',
#    'entity_value': 'medical service',
#    'start_position': 5785,
#    'end_position': 5800},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'demand ischemia',
#    'start_position': 5829,
#    'end_position': 5844},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'original hypertensive urgency',
#    'start_position': 5859,
#    'end_position': 5888},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'persistent elevation of trop',
#    'start_position': 5894,
#    'end_position': 5922},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'ESRD',
#    'start_position': 5929,
#    'end_position': 5933},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'aspirin',
#    'start_position': 5956,
#    'end_position': 5963},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'metoprolol',
#    'start_position': 5966,
#    'end_position': 5976},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'nifedipine',
#    'start_position': 5979,
#    'end_position': 5989},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'ESRD',
#    'start_position': 5994,
#    'end_position': 5998},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'DM',
#    'start_position': 6023,
#    'end_position': 6025},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'HTN',
#    'start_position': 6030,
#    'end_position': 6033},
#   {'entity_type': 'OCCURRENCE',
#    'entity_value': 'tolerating',
#    'start_position': 6039,
#    'end_position': 6049},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'HD',
#    'start_position': 6050,
#    'end_position': 6052},
#   {'entity_type': 'OCCURRENCE',
#    'entity_value': 'well',
#    'start_position': 6053,
#    'end_position': 6057},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'dialysis',
#    'start_position': 6074,
#    'end_position': 6082},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'difficulty',
#    'start_position': 6091,
#    'end_position': 6101},
#   {'entity_type': 'OCCURRENCE',
#    'entity_value': 'discharged',
#    'start_position': 6124,
#    'end_position': 6134},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'diaphoretic',
#    'start_position': 616,
#    'end_position': 627},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'current dialysis schedule',
#    'start_position': 6162,
#    'end_position': 6187},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'vancomycin',
#    'start_position': 6237,
#    'end_position': 6247},
#   {'entity_type': 'CLINICAL_DEPT',
#    'entity_value': 'dialysis',
#    'start_position': 6251,
#    'end_position': 6259},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'his PORT line infection',
#    'start_position': 6306,
#    'end_position': 6329},
#   {'entity_type': 'TEST',
#    'entity_value': 'levels',
#    'start_position': 6345,
#    'end_position': 6351},
#   {'entity_type': 'CLINICAL_DEPT',
#    'entity_value': 'dialysis',
#    'start_position': 6361,
#    'end_position': 6369},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'vancomycin',
#    'start_position': 6388,
#    'end_position': 6398},
#   {'entity_type': 'TEST',
#    'entity_value': 'surveillance cultures',
#    'start_position': 6428,
#    'end_position': 6449},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'pain',
#    'start_position': 645,
#    'end_position': 649},
#   {'entity_type': 'CLINICAL_DEPT',
#    'entity_value': 'dialysis',
#    'start_position': 6465,
#    'end_position': 6473},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'presumptively replacement of PORT',
#    'start_position': 6510,
#    'end_position': 6543},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'vomiting clear substance',
#    'start_position': 653,
#    'end_position': 677},
#   {'entity_type': 'CLINICAL_DEPT',
#    'entity_value': 'interventional radiology',
#    'start_position': 6563,
#    'end_position': 6587},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'calcium acetate',
#    'start_position': 6637,
#    'end_position': 6652},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'AV fistula',
#    'start_position': 6681,
#    'end_position': 6691},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'numerous clots',
#    'start_position': 6706,
#    'end_position': 6720},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'AV fistula',
#    'start_position': 6724,
#    'end_position': 6734},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'infection',
#    'start_position': 6749,
#    'end_position': 6758},
#   {'entity_type': 'OCCURRENCE',
#    'entity_value': 'tolerating',
#    'start_position': 6775,
#    'end_position': 6785},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'dialysis',
#    'start_position': 6786,
#    'end_position': 6794},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'difficulty',
#    'start_position': 6803,
#    'end_position': 6813},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'subtherapeuticon INR',
#    'start_position': 6823,
#    'end_position': 6843},
#   {'entity_type': 'OCCURRENCE',
#    'entity_value': 'admission',
#    'start_position': 6847,
#    'end_position': 6856},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'heparin gtt',
#    'start_position': 6877,
#    'end_position': 6888},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'coumadin',
#    'start_position': 6891,
#    'end_position': 6899},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'PORT removal',
#    'start_position': 6918,
#    'end_position': 6930},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'ativan',
#    'start_position': 693,
#    'end_position': 699},
#   {'entity_type': 'OCCURRENCE',
#    'entity_value': 'discharged',
#    'start_position': 6961,
#    'end_position': 6971},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'coumadin',
#    'start_position': 7002,
#    'end_position': 7010},
#   {'entity_type': 'TEST',
#    'entity_value': 'goal INR',
#    'start_position': 7034,
#    'end_position': 7042},
#   {'entity_type': 'OCCURRENCE',
#    'entity_value': 'discharged',
#    'start_position': 7064,
#    'end_position': 7074},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'vancomycin',
#    'start_position': 7136,
#    'end_position': 7146},
#   {'entity_type': 'CLINICAL_DEPT',
#    'entity_value': 'hemodialysis',
#    'start_position': 7150,
#    'end_position': 7162},
#   {'entity_type': 'PROBLEM',
#    'entity_value': 'his PORT line infection',
#    'start_position': 7167,
#    'end_position': 7190},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'ativan',
#    'start_position': 719,
#    'end_position': 725},
#   {'entity_type': 'CLINICAL_DEPT',
#    'entity_value': 'interventional radiology',
#    'start_position': 7222,
#    'end_position': 7246},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'his PORT',
#    'start_position': 7272,
#    'end_position': 7280},
#   {'entity_type': 'TEST',
#    'entity_value': 'his surveillance cultures',
#    'start_position': 7309,
#    'end_position': 7334},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'dialysis',
#    'start_position': 7340,
#    'end_position': 7348},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'dilaudid',
#    'start_position': 736,
#    'end_position': 744},
#   {'entity_type': 'OCCURRENCE',
#    'entity_value': 'negative',
#    'start_position': 7356,
#    'end_position': 7364},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'labetolol',
#    'start_position': 747,
#    'end_position': 756},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'hydralazine',
#    'start_position': 774,
#    'end_position': 785},
#   {'entity_type': 'OCCURRENCE',
#    'entity_value': 'good response',
#    'start_position': 807,
#    'end_position': 820},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'NS',
#    'start_position': 848,
#    'end_position': 850},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'labetolol gtt',
#    'start_position': 870,
#    'end_position': 883},
#   {'entity_type': 'TEST',
#    'entity_value': 'BP',
#    'start_position': 888,
#    'end_position': 890},
#   {'entity_type': 'OCCURRENCE',
#    'entity_value': 'decreased',
#    'start_position': 891,
#    'end_position': 900},
#   {'entity_type': 'OCCURRENCE',
#    'entity_value': 'Tranferred',
#    'start_position': 913,
#    'end_position': 923},
#   {'entity_type': 'CLINICAL_DEPT',
#    'entity_value': 'CMED CCU',
#    'start_position': 927,
#    'end_position': 935},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'further management',
#    'start_position': 940,
#    'end_position': 958},
#   {'entity_type': 'TREATMENT',
#    'entity_value': 'labetolol gtt',
#    'start_position': 968,
#    'end_position': 981}],
#  'tokens': [{'text': '\n',
#    'idx': 0,
#    'tag_': '_SP',
#    'pos_': 'SPACE',
#    'dep_': 'punct',
#    'lemma_': '\n',
#    '_': {}},
#   {'text': 'Admission',
#    'idx': 1,
#    'tag_': 'NN',
#    'pos_': 'NOUN',
#    'dep_': 'compound',
#    'lemma_': 'admission',
#    '_': {}},
#   {'text': 'Date',
#    'idx': 11,
#    'tag_': 'NN',
#    'pos_': 'NOUN',
#    'dep_': 'nsubj',
#    'lemma_': 'date',
#    '_': {}},
#   {'text': ':',
#    'idx': 16,
#    'tag_': ':',
#    'pos_': 'PUNCT',
#    'dep_': 'punct',
#    'lemma_': ':',
#    '_': {}},
#   {'text': '\n',
#    'idx': 17,
#    'tag_': '_SP',
#    'pos_': 'SPACE',
#    'dep_': 'appos',
#    'lemma_': '\n',
#    '_': {}},
#   {'text': '2019',
#    'idx': 18,
#    'tag_': 'CD',
#    'pos_': 'NUM',
#    'dep_': 'nummod',
#    'lemma_': '2019',
#    '_': {}},
#   {'text': '-',
#    'idx': 22,
#    'tag_': 'CD',
#    'pos_': 'NUM',
#    'dep_': 'appos',
#    'lemma_': '-',
#    '_': {}},
#   {'text': '01',
#    'idx': 23,
#    'tag_': 'CD',
#    'pos_': 'NUM',
#    'dep_': 'npadvmod',
#    'lemma_': '01',
#    '_': {}},
#   {'text': '-',
#    'idx': 25,
#    'tag_': 'CD',
#    'pos_': 'NUM',
#    'dep_': 'pobj',
#    'lemma_': '-',
#    '_': {}},
#   {'text': '19',
#    'idx': 26,
#    'tag_': 'CD',
#    'pos_': 'NUM',
#    'dep_': 'nummod',
#    'lemma_': '19',
#    '_': {}},
#   {'text': '\n',
#    'idx': 28,
#    'tag_': '_SP',
#    'pos_': 'SPACE',
#    'dep_': 'punct',
#    'lemma_': '\n',
#    '_': {}},
#   {'text': 'Discharge',
#    'idx': 29,
#    'tag_': 'NN',
#    'pos_': 'NOUN',
#    'dep_': 'compound',
#    'lemma_': 'discharge',
#    '_': {}},
#   {'text': 'Date',
#    'idx': 39,
#    'tag_': 'NN',
#    'pos_': 'NOUN',
#    'dep_': 'appos',
#    'lemma_': 'date',
#    '_': {}},
#   {'text': ':',
#    'idx': 44,
#    'tag_': ':',
#    'pos_': 'PUNCT',
#    'dep_': 'punct',
#    'lemma_': ':',
#    '_': {}},
#   {'text': '\n',
#    'idx': 45,
#    'tag_': '_SP',
#    'pos_': 'SPACE',
#    'dep_': 'appos',
#    'lemma_': '\n',
#    '_': {}},
#   {'text': '2019',
#    'idx': 46,
#    'tag_': 'CD',
#    'pos_': 'NUM',
#    'dep_': 'appos',
#    'lemma_': '2019',
#    '_': {}},
#   {'text': '-',
#    'idx': 50,
#    'tag_': 'CD',
#    'pos_': 'NUM',
#    'dep_': 'appos',
#    'lemma_': '-',
#    '_': {}},
#   {'text': '01',
#    'idx': 51,
#    'tag_': 'CD',
#    'pos_': 'NUM',
#    'dep_': 'appos',
#    'lemma_': '01',
#    '_': {}},
#   {'text': '-',
#    'idx': 53,
#    'tag_': 'CD',
#    'pos_': 'NUM',
#    'dep_': 'appos',
#    'lemma_': '-',
#    '_': {}},
#   {'text': '24',
#    'idx': 54,
#    'tag_': 'CD',
#    'pos_': 'NUM',
#    'dep_': 'appos',
#    'lemma_': '24',
#    '_': {}},
#   {'text': '\n',
#    'idx': 56,
#    'tag_': '_SP',
#    'pos_': 'SPACE',
#    'dep_': 'punct',
#    'lemma_': '\n',
#    '_': {}},
#   {'text': 'Service',
#    'idx': 57,
#    'tag_': 'NN',
#    'pos_': 'NOUN',
#    'dep_': 'appos',
#    'lemma_': 'service',
#    '_': {}},
#   {'text': ':',
#    'idx': 65,
#    'tag_': ':',
#    'pos_': 'PUNCT',
#    'dep_': 'punct',
#    'lemma_': ':',
#    '_': {}},
#   {'text': 'MEDICINE',
#    'idx': 67,
#    'tag_': 'NN',
#    'pos_': 'NOUN',
#    'dep_': 'appos',
#    'lemma_': 'medicine',
#    '_': {}},
#   {'text': '\n',
#    'idx': 75,
#    'tag_': '_SP',
#    'pos_': 'SPACE',
#    'dep_': 'punct',
#    'lemma_': '\n',
#    '_': {}},
#   {'text': 'Allergies',
#    'idx': 76,
#    'tag_': 'NNS',
#    'pos_': 'NOUN',
#    'dep_': 'appos',
#    'lemma_': 'allergy',
#    '_': {}},
#   {'text': ':',
#    'idx': 86,
#    'tag_': ':',
#    'pos_': 'PUNCT',
#    'dep_': 'punct',
#    'lemma_': ':',
#    '_': {}},
#   {'text': '\n',
#    'idx': 87,
#    'tag_': '_SP',
#    'pos_': 'SPACE',
#    'dep_': 'punct',
#    'lemma_': '\n',
#    '_': {}},
#   {'text': 'History',
#    'idx': 88,
#    'tag_': 'NN',
#    'pos_': 'NOUN',
#    'dep_': 'appos',
#    'lemma_': 'history',
#    '_': {}},
#   {'text': 'of',
#    'idx': 96,
#    'tag_': 'IN',
#    'pos_': 'ADP',
#    'dep_': 'prep',
#    'lemma_': 'of',
#    '_': {}},
#   {'text': 'Present',
#    'idx': 99,
#    'tag_': 'JJ',
#    'pos_': 'ADJ',
#    'dep_': 'amod',
#    'lemma_': 'present',
#    '_': {}},
#   {'text': 'Illness',
#    'idx': 107,
#    'tag_': 'NN',
#    'pos_': 'NOUN',
#    'dep_': 'pobj',
#    'lemma_': 'illness',
#    '_': {}},
#   {'text': ':',
#    'idx': 115,
#    'tag_': ':',
#    'pos_': 'PUNCT',
#    'dep_': 'punct',
#    'lemma_': ':',
#    '_': {}},
#   {'text': '\n',
#    'idx': 116,
#    'tag_': '_SP',
#    'pos_': 'SPACE',
#    'dep_': 'punct',
#    'lemma_': '\n',
#    '_': {}},
#   {'text': 'This',
#    'idx': 117,
#    'tag_': 'DT',
#    'pos_': 'DET',
#    'dep_': 'nsubj',
#    'lemma_': 'this',
#    '_': {}},
#   {'text': 'is',
#    'idx': 122,
#    'tag_': 'VBZ',
#    'pos_': 'AUX',
#    'dep_': 'ROOT',
#    'lemma_': 'be',
#    '_': {}},
#   {'text': 'a',
#    'idx': 125,
#    'tag_': 'DT',
#    'pos_': 'DET',
#    'dep_': 'det',
#    'lemma_': 'a',
#    '_': {}},
#   {'text': '37',
#    'idx': 127,
#    'tag_': 'CD',
#    'pos_': 'NUM',
#    'dep_': 'nummod',
#    'lemma_': '37',
#    '_': {}},
#   {'text': 'y',
#    'idx': 130,
#    'tag_': 'NN',
#    'pos_': 'NOUN',
#    'dep_': 'compound',
#    'lemma_': 'y',
#    '_': {}},
#   {'text': '/',
#    'idx': 131,
#    'tag_': 'NN',
#    'pos_': 'NOUN',
#    'dep_': 'npadvmod',
#    'lemma_': '/',
#    '_': {}},
#   {'text': 'o',
#    'idx': 132,
#    'tag_': 'NN',
#    'pos_': 'NOUN',
#    'dep_': 'compound',
#    'lemma_': 'o',
#    '_': {}},
#   {'text': 'male',
#    'idx': 134,
#    'tag_': 'NN',
#    'pos_': 'NOUN',
#    'dep_': 'compound',
#    'lemma_': 'male',
#    '_': {}},
#   {'text': 'patient',
#    'idx': 139,
#    'tag_': 'NN',
#    'pos_': 'NOUN',
#    'dep_': 'attr',
#    'lemma_': 'patient',
#    '_': {}},
#   {'text': 'with',
#    'idx': 147,
#    'tag_': 'IN',
#    'pos_': 'ADP',
#    'dep_': 'prep',
#    'lemma_': 'with',
#    '_': {}},
#   {'text': 'PMH',
#    'idx': 152,
#    'tag_': 'NNP',
#    'pos_': 'PROPN',
#    'dep_': 'compound',
#    'lemma_': 'PMH',
#    '_': {}},
#   {'text': 'Type',
#    'idx': 156,
#    'tag_': 'NNP',
#    'pos_': 'PROPN',
#    'dep_': 'compound',
#    'lemma_': 'Type',
#    '_': {}},
#   {'text': 'I',
#    'idx': 161,
#    'tag_': 'NN',
#    'pos_': 'NOUN',
#    'dep_': 'compound',
#    'lemma_': 'i',
#    '_': {}},
#   {'text': 'DM',
#    'idx': 163,
#    'tag_': 'NNP',
#    'pos_': 'PROPN',
#    'dep_': 'pobj',
#    'lemma_': 'DM',
#    '_': {}},
#   {'text': ',',
#    'idx': 166,
#    'tag_': ',',
#    'pos_': 'PUNCT',
#    'dep_': 'punct',
#    'lemma_': ',',
#    '_': {}},
#   {'text': 'HTN',
#    'idx': 168,
#    'tag_': 'NNP',
#    'pos_': 'PROPN',
#    'dep_': 'appos',
#    'lemma_': 'HTN',
#    '_': {}},
#   {'text': ',',
#    'idx': 172,
#    'tag_': ',',
#    'pos_': 'PUNCT',
#    'dep_': 'punct',
#    'lemma_': ',',
#    '_': {}},
#   {'text': 'gastroparesis',
#    'idx': 174,
#    'tag_': 'NNS',
#    'pos_': 'NOUN',
#    'dep_': 'appos',
#    'lemma_': 'gastroparesi',
#    '_': {}},
#   {'text': ',',
#    'idx': 188,
#    'tag_': ',',
#    'pos_': 'PUNCT',
#    'dep_': 'punct',
#    'lemma_': ',',
#    '_': {}},
#   {'text': 'ESRD',
#    'idx': 190,
#    'tag_': 'NN',
#    'pos_': 'NOUN',
#    'dep_': 'appos',
#    'lemma_': 'esrd',
#    '_': {}},
#   {'text': 'on',
#    'idx': 195,
#    'tag_': 'IN',
#    'pos_': 'ADP',
#    'dep_': 'prep',
#    'lemma_': 'on',
#    '_': {}},
#   {'text': 'HD',
#    'idx': 198,
#    'tag_': 'NNP',
#    'pos_': 'PROPN',
#    'dep_': 'pobj',
#    'lemma_': 'HD',
#    '_': {}},
#   {'text': '(',
#    'idx': 201,
#    'tag_': '-LRB-',
#    'pos_': 'PUNCT',
#    'dep_': 'punct',
#    'lemma_': '(',
#    '_': {}},
#   {'text': 'last',
#    'idx': 203,
#    'tag_': 'JJ',
#    'pos_': 'ADJ',
#    'dep_': 'appos',
#    'lemma_': 'last',
#    '_': {}},
#   {'text': 'in',
#    'idx': 208,
#    'tag_': 'IN',
#    'pos_': 'ADP',
#    'dep_': 'prep',
#    'lemma_': 'in',
#    '_': {}},
#   {'text': '12/26',
#    'idx': 211,
#    'tag_': 'CD',
#    'pos_': 'NUM',
#    'dep_': 'pobj',
#    'lemma_': '12/26',
#    '_': {}},
#   {'text': 'per',
#    'idx': 217,
#    'tag_': 'IN',
#    'pos_': 'ADP',
#    'dep_': 'prep',
#    'lemma_': 'per',
#    '_': {}},
#   {'text': 'patient',
#    'idx': 221,
#    'tag_': 'NN',
#    'pos_': 'NOUN',
#    'dep_': 'pobj',
#    'lemma_': 'patient',
#    '_': {}},
#   {'text': ')',
#    'idx': 229,
#    'tag_': '-RRB-',
#    'pos_': 'PUNCT',
#    'dep_': 'punct',
#    'lemma_': ')',
#    '_': {}},
#   {'text': 'who',
#    'idx': 231,
#    'tag_': 'WP',
#    'pos_': 'PRON',
#    'dep_': 'nsubj',
#    'lemma_': 'who',
#    '_': {}},
#   {'text': 'presents',
#    'idx': 235,
#    'tag_': 'VBZ',
#    'pos_': 'VERB',
#    'dep_': 'relcl',
#    'lemma_': 'present',
#    '_': {}},
#   {'text': 'to',
#    'idx': 244,
#    'tag_': 'IN',
#    'pos_': 'ADP',
#    'dep_': 'prep',
#    'lemma_': 'to',
#    '_': {}},
#   {'text': 'CMED',
#    'idx': 247,
#    'tag_': 'NNP',
#    'pos_': 'PROPN',
#    'dep_': 'compound',
#    'lemma_': 'CMED',
#    '_': {}},
#   {'text': 'CCU',
#    'idx': 252,
#    'tag_': 'NNP',
#    'pos_': 'PROPN',
#    'dep_': 'pobj',
#    'lemma_': 'CCU',
#    '_': {}},
#   {'text': 'with',
#    'idx': 256,
#    'tag_': 'IN',
#    'pos_': 'ADP',
#    'dep_': 'prep',
#    'lemma_': 'with',
#    '_': {}},
#   {'text': 'hypertensive',
#    'idx': 261,
#    'tag_': 'JJ',
#    'pos_': 'ADJ',
#    'dep_': 'amod',
#    'lemma_': 'hypertensive',
#    '_': {}},
#   {'text': 'urgency',
#    'idx': 274,
#    'tag_': 'NN',
#    'pos_': 'NOUN',
#    'dep_': 'pobj',
#    'lemma_': 'urgency',
#    '_': {}},
#   {'text': 'unable',
#    'idx': 282,
#    'tag_': 'JJ',
#    'pos_': 'ADJ',
#    'dep_': 'amod',
#    'lemma_': 'unable',
#    '_': {}},
#   {'text': 'from',
#    'idx': 289,
#    'tag_': 'IN',
#    'pos_': 'ADP',
#    'dep_': 'prep',
#    'lemma_': 'from',
#    '_': {}},
#   {'text': 'the',
#    'idx': 294,
#    'tag_': 'DT',
#    'pos_': 'DET',
#    'dep_': 'det',
#    'lemma_': 'the',
#    '_': {}},
#   {'text': 'Larry',
#    'idx': 298,
#    'tag_': 'NNP',
#    'pos_': 'PROPN',
#    'dep_': 'pobj',
#    'lemma_': 'Larry',
#    '_': {}},
#   {'text': '.',
#    'idx': 304,
#    'tag_': '.',
#    'pos_': 'PUNCT',
#    'dep_': 'punct',
#    'lemma_': '.',
#    '_': {}},
#   {'text': '\n',
#    'idx': 305,
#    'tag_': '_SP',
#    'pos_': 'SPACE',
#    'dep_': 'auxpass',
#    'lemma_': '\n',
#    '_': {}},
#   {'text': 'The',
#    'idx': 306,
#    'tag_': 'DT',
#    'pos_': 'DET',
#    'dep_': 'det',
#    'lemma_': 'the',
#    '_': {}},
#   {'text': 'patient',
#    'idx': 310,
#    'tag_': 'NN',
#    'pos_': 'NOUN',
#    'dep_': 'nsubjpass',
#    'lemma_': 'patient',
#    '_': {}},
#   {'text': 'early',
#    'idx': 318,
#    'tag_': 'RB',
#    'pos_': 'ADV',
#    'dep_': 'advmod',
#    'lemma_': 'early',
#    '_': {}},
#   {'text': 'this',
#    'idx': 324,
#    'tag_': 'DT',
#    'pos_': 'DET',
#    'dep_': 'det',
#    'lemma_': 'this',
#    '_': {}},
#   {'text': 'morning',
#    'idx': 329,
#    'tag_': 'NN',
#    'pos_': 'NOUN',
#    'dep_': 'npadvmod',
#    'lemma_': 'morning',
#    '_': {}},
#   {'text': 'to',
#    'idx': 337,
#    'tag_': 'IN',
#    'pos_': 'ADP',
#    'dep_': 'prep',
#    'lemma_': 'to',
#    '_': {}},
#   {'text': 'the',
#    'idx': 340,
#    'tag_': 'DT',
#    'pos_': 'DET',
#    'dep_': 'det',
#    'lemma_': 'the',
#    '_': {}},
#   {'text': 'Ruthie',
#    'idx': 344,
#    'tag_': 'NNP',
#    'pos_': 'PROPN',
#    'dep_': 'pobj',
#    'lemma_': 'Ruthie',
#    '_': {}},
#   {'text': 'with',
#    'idx': 351,
#    'tag_': 'IN',
#    'pos_': 'ADP',
#    'dep_': 'prep',
#    'lemma_': 'with',
#    '_': {}},
#   {'text': 'his',
#    'idx': 356,
#    'tag_': 'PRP$',
#    'pos_': 'PRON',
#    'dep_': 'poss',
#    'lemma_': 'his',
#    '_': {}},
#   {'text': 'usual',
#    'idx': 360,
#    'tag_': 'JJ',
#    'pos_': 'ADJ',
#    'dep_': 'amod',
#    'lemma_': 'usual',
#    '_': {}},
#   {'text': 'nausea',
#    'idx': 366,
#    'tag_': 'NN',
#    'pos_': 'NOUN',
#    'dep_': 'pobj',
#    'lemma_': 'nausea',
#    '_': {}},
#   {'text': ',',
#    'idx': 373,
#    'tag_': ',',
#    'pos_': 'PUNCT',
#    'dep_': 'punct',
#    'lemma_': ',',
#    '_': {}},
#   {'text': 'vomiting',
#    'idx': 375,
#    'tag_': 'NN',
#    'pos_': 'NOUN',
#    'dep_': 'appos',
#    'lemma_': 'vomiting',
#    '_': {}},
#   {'text': ',',
#    'idx': 384,
#    'tag_': ',',
#    'pos_': 'PUNCT',
#    'dep_': 'punct',
#    'lemma_': ',',
#    '_': {}},
#   {'text': 'abdominal',
#    'idx': 386,
#    'tag_': 'JJ',
#    'pos_': 'ADJ',
#    'dep_': 'amod',
#    'lemma_': 'abdominal',
#    '_': {}},
#   {'text': 'pain',
#    'idx': 396,
#    'tag_': 'NN',
#    'pos_': 'NOUN',
#    'dep_': 'appos',
#    'lemma_': 'pain',
#    '_': {}},
#   {'text': 'and',
#    'idx': 401,
#    'tag_': 'CC',
#    'pos_': 'CCONJ',
#    'dep_': 'cc',
#    'lemma_': 'and',
#    '_': {}},
#   {'text': 'was',
#    'idx': 405,
#    'tag_': 'VBD',
#    'pos_': 'AUX',
#    'dep_': 'auxpass',
#    'lemma_': 'be',
#    '_': {}},
#   {'text': 'found',
#    'idx': 409,
#    'tag_': 'VBN',
#    'pos_': 'VERB',
#    'dep_': 'ROOT',
#    'lemma_': 'find',
#    '_': {}},
#   {'text': 'to',
#    'idx': 415,
#    'tag_': 'TO',
#    'pos_': 'PART',
#    'dep_': 'aux',
#    'lemma_': 'to',
#    '_': {}},
#   {'text': 'be',
#    'idx': 418,
#    'tag_': 'VB',
#    'pos_': 'VERB',
#    'dep_': 'xcomp',
#    'lemma_': 'be',
#    '_': {}},
#   {'text': 'hypertensive',
#    'idx': 421,
#    'tag_': 'JJ',
#    'pos_': 'ADJ',
#    'dep_': 'acomp',
#    'lemma_': 'hypertensive',
#    '_': {}},
#   {'text': 'to',
#    'idx': 434,
#    'tag_': 'IN',
#    'pos_': 'ADP',
#    'dep_': 'prep',
#    'lemma_': 'to',
#    '_': {}},
#   {'text': '256/110',
#    'idx': 437,
#    'tag_': 'CD',
#    'pos_': 'NUM',
#    'dep_': 'pobj',
#    'lemma_': '256/110',
#    '_': {}},
#   {'text': ',',
#    'idx': 445,
#    'tag_': ',',
#    'pos_': 'PUNCT',
#    'dep_': 'punct',
#    'lemma_': ',',
#    '_': {}},
#   {'text': 'HR',
#    'idx': 447,
#    'tag_': 'NN',
#    'pos_': 'NOUN',
#    'dep_': 'npadvmod',
#    'lemma_': 'hr',
#    '_': {}},
#   {'text': '102',
#    'idx': 450,
#    'tag_': 'CD',
#    'pos_': 'NUM',
#    'dep_': 'nummod',
#    'lemma_': '102',
#    '_': {}},
#   {'text': ',',
#    'idx': 454,
#    'tag_': ',',
#    'pos_': 'PUNCT',
#    'dep_': 'punct',
#    'lemma_': ',',
#    '_': {}},
#   {'text': 'T',
#    'idx': 456,
#    'tag_': 'NN',
#    'pos_': 'NOUN',
#    'dep_': 'appos',
#    'lemma_': 't',
#    '_': {}},
#   {'text': '99.2',
#    'idx': 458,
#    'tag_': 'CD',
#    'pos_': 'NUM',
#    'dep_': 'nummod',
#    'lemma_': '99.2',
#    '_': {}},
#   {'text': ',',
#    'idx': 463,
#    'tag_': ',',
#    'pos_': 'PUNCT',
#    'dep_': 'punct',
#    'lemma_': ',',
#    '_': {}},
#   {'text': 'RR',
#    'idx': 465,
#    'tag_': 'NN',
#    'pos_': 'NOUN',
#    'dep_': 'appos',
#    'lemma_': 'rr',
#    '_': {}},
#   {'text': '22',
#    'idx': 468,
#    'tag_': 'CD',
#    'pos_': 'NUM',
#    'dep_': 'nummod',
#    'lemma_': '22',
#    '_': {}},
# ...
#    'lemma_': 'place',
#    '_': {}},
#   {'text': ',',
#    'idx': 4510,
#    'tag_': ',',
#    'pos_': 'PUNCT',
#    'dep_': 'punct',
#    'lemma_': ',',
#    '_': {}},
#   {'text': 'however',
#    'idx': 4512,
#    'tag_': 'RB',
#    'pos_': 'ADV',
#    'dep_': 'advmod',
#    'lemma_': 'however',
#    '_': {}},
#   {'text': 'removed',
#    'idx': 4520,
#    'tag_': 'VBN',
#    'pos_': 'VERB',
#    'dep_': 'dep',
#    'lemma_': 'remove',
#    '_': {}},
#   {'text': 'as',
#    'idx': 4528,
#    'tag_': 'IN',
#    'pos_': 'ADP',
#    'dep_': 'mark',
#    'lemma_': 'as',
#    '_': {}},
#   {'text': 'it',
#    'idx': 4531,
#    'tag_': 'PRP',
#    'pos_': 'PRON',
#    'dep_': 'nsubj',
#    'lemma_': 'it',
#    '_': {}},
#   {'text': 'is',
#    'idx': 4534,
#    'tag_': 'VBZ',
#    'pos_': 'VERB',
#    'dep_': 'advcl',
#    'lemma_': 'be',
#    '_': {}},
#   {'text': 'unclear',
#    'idx': 4537,
#    'tag_': 'JJ',
#    'pos_': 'ADJ',
#    'dep_': 'acomp',
#    'lemma_': 'unclear',
#    '_': {}},
#   {'text': 'if',
#    'idx': 4545,
#    'tag_': 'IN',
#    'pos_': 'SCONJ',
#    'dep_': 'mark',
#    'lemma_': 'if',
#    '_': {}},
#   {'text': 'pt',
#    'idx': 4548,
#    'tag_': 'NN',
#    'pos_': 'NOUN',
#    'dep_': 'nsubj',
#    'lemma_': 'pt',
#    '_': {}},
#   {'text': 'can',
#    'idx': 4551,
#    'tag_': 'MD',
#    'pos_': 'AUX',
#    'dep_': 'aux',
#    'lemma_': 'can',
#    '_': {}},
#   {'text': 'reliably',
#    'idx': 4555,
#    'tag_': 'RB',
#    'pos_': 'ADV',
#    'dep_': 'advmod',
#    'lemma_': 'reliably',
#    '_': {}},
#   {'text': 'flush',
#    'idx': 4564,
#    'tag_': 'VB',
#    'pos_': 'VERB',
#    'dep_': 'ccomp',
#    'lemma_': 'flush',
#    '_': {}},
#   {'text': 'this',
#    'idx': 4570,
#    'tag_': 'DT',
#    'pos_': 'DET',
#    'dep_': 'dobj',
#    'lemma_': 'this',
#    '_': {}},
#   {'text': '.',
#    'idx': 4575,
#    'tag_': '.',
#    'pos_': 'PUNCT',
#    'dep_': 'punct',
#    'lemma_': '.',
#    '_': {}},
#   {'text': '\n',
#    'idx': 4576,
#    'tag_': '_SP',
#    'pos_': 'SPACE',
#    'dep_': 'punct',
#    'lemma_': '\n',
#    '_': {}},
#   {'text': 'PORT',
#    'idx': 4577,
#    'tag_': 'NNP',
#    'pos_': 'PROPN',
#    'dep_': 'nsubjpass',
#    'lemma_': 'PORT',
#    '_': {}},
#   {'text': 'will',
#    'idx': 4582,
#    'tag_': 'MD',
#    'pos_': 'AUX',
#    'dep_': 'aux',
#    'lemma_': 'will',
#    '_': {}},
#   {'text': 'be',
#    'idx': 4587,
#    'tag_': 'VB',
#    'pos_': 'AUX',
#    'dep_': 'auxpass',
#    'lemma_': 'be',
#    '_': {}},
#   {'text': 'replaced',
#    'idx': 4590,
#    'tag_': 'VBN',
#    'pos_': 'VERB',
#    'dep_': 'punct',
#    'lemma_': 'replace',
#    '_': {}},
#   {'text': 'on',
#    'idx': 4599,
#    'tag_': 'IN',
#    'pos_': 'ADP',
#    'dep_': 'prep',
#    'lemma_': 'on',
#    '_': {}},
#   {'text': '2019',
#    'idx': 4602,
#    'tag_': 'CD',
#    'pos_': 'NUM',
#    'dep_': 'pobj',
#    'lemma_': '2019',
#    '_': {}},
#   {'text': '-',
#    'idx': 4606,
#    'tag_': 'CD',
#    'pos_': 'NUM',
#    'dep_': 'pobj',
#    'lemma_': '-',
#    '_': {}},
#   {'text': '02',
#    'idx': 4607,
#    'tag_': 'CD',
#    'pos_': 'NUM',
#    'dep_': 'pobj',
#    'lemma_': '02',
#    '_': {}},
#   {'text': '-',
#    'idx': 4609,
#    'tag_': 'CD',
#    'pos_': 'NUM',
#    'dep_': 'pobj',
#    'lemma_': '-',
#    '_': {}},
#   {'text': '11',
#    'idx': 4610,
#    'tag_': 'CD',
#    'pos_': 'NUM',
#    'dep_': 'pobj',
#    'lemma_': '11',
#    '_': {}},
#   {'text': 'per',
#    'idx': 4613,
#    'tag_': 'IN',
#    'pos_': 'ADP',
#    'dep_': 'prep',
#    'lemma_': 'per',
#    '_': {}},
#   {'text': 'IR',
#    'idx': 4617,
#    'tag_': 'NN',
#    'pos_': 'NOUN',
#    'dep_': 'pobj',
#    'lemma_': 'ir',
#    '_': {}},
#   {'text': '(',
#    'idx': 4620,
#    'tag_': '-LRB-',
#    'pos_': 'PUNCT',
#    'dep_': 'punct',
#    'lemma_': '(',
#    '_': {}},
#   {'text': 'Dr.',
#    'idx': 4622,
#    'tag_': 'NNP',
#    'pos_': 'PROPN',
#    'dep_': 'compound',
#    'lemma_': 'Dr.',
#    '_': {}},
#   {'text': 'Welsh',
#    'idx': 4626,
#    'tag_': 'NNP',
#    'pos_': 'PROPN',
#    'dep_': 'nsubj',
#    'lemma_': 'Welsh',
#    '_': {}},
#   {'text': 'placed',
#    'idx': 4632,
#    'tag_': 'VBD',
#    'pos_': 'VERB',
#    'dep_': 'parataxis',
#    'lemma_': 'place',
#    '_': {}},
#   {'text': 'last',
#    'idx': 4639,
#    'tag_': 'JJ',
#    'pos_': 'ADJ',
#    'dep_': 'amod',
#    'lemma_': 'last',
#    '_': {}},
#   {'text': 'PORT',
#    'idx': 4644,
#    'tag_': 'NNP',
#    'pos_': 'PROPN',
#    'dep_': 'dobj',
#    'lemma_': 'PORT',
#    '_': {}},
#   {'text': ',',
#    'idx': 4649,
#    'tag_': ',',
#    'pos_': 'PUNCT',
#    'dep_': 'punct',
#    'lemma_': ',',
#    '_': {}},
#   {'text': 'then',
#    'idx': 4651,
#    'tag_': 'RB',
#    'pos_': 'ADV',
#    'dep_': 'advmod',
#    'lemma_': 'then',
#    '_': {}},
#   {'text': 'removed',
#    'idx': 4656,
#    'tag_': 'VBD',
#    'pos_': 'VERB',
#    'dep_': 'dep',
#    'lemma_': 'remove',
#    '_': {}},
#   {'text': 'it',
#    'idx': 4664,
#    'tag_': 'PRP',
#    'pos_': 'PRON',
#    'dep_': 'dobj',
#    'lemma_': 'it',
#    '_': {}},
#   {'text': 'on',
#    'idx': 4667,
#    'tag_': 'IN',
#    'pos_': 'ADP',
#    'dep_': 'prep',
#    'lemma_': 'on',
#    '_': {}},
#   {'text': '01',
#    'idx': 4670,
#    'tag_': 'CD',
#    'pos_': 'NUM',
#    'dep_': 'pobj',
#    'lemma_': '01',
#    '_': {}},
#   {'text': '-',
#    'idx': 4672,
#    'tag_': 'CD',
#    'pos_': 'NUM',
#    'dep_': 'pobj',
#    'lemma_': '-',
#    '_': {}},
#   {'text': '23',
#    'idx': 4673,
#    'tag_': 'CD',
#    'pos_': 'NUM',
#    'dep_': 'pobj',
#    'lemma_': '23',
#    '_': {}},
#   {'text': ')',
#    'idx': 4676,
#    'tag_': '-RRB-',
#    'pos_': 'PUNCT',
#    'dep_': 'punct',
#    'lemma_': ')',
#    '_': {}},
#   {'text': ',',
#    'idx': 4677,
#    'tag_': '-RRB-',
#    'pos_': 'PUNCT',
#    'dep_': 'punct',
#    'lemma_': ',',
#    '_': {}},
#   {'text': 'ordered',
#    'idx': 4679,
#    'tag_': 'VBN',
#    'pos_': 'VERB',
#    'dep_': 'advcl',
#    'lemma_': 'order',
#    '_': {}},
#   {'text': 'placed',
#    'idx': 4687,
#    'tag_': 'VBN',
#    'pos_': 'VERB',
#    'dep_': 'xcomp',
#    'lemma_': 'place',
#    '_': {}},
#   {'text': 'in',
#    'idx': 4694,
#    'tag_': 'IN',
#    'pos_': 'ADP',
#    'dep_': 'prep',
#    'lemma_': 'in',
#    '_': {}},
#   {'text': 'OMR',
#    'idx': 4697,
#    'tag_': 'NNP',
#    'pos_': 'PROPN',
#    'dep_': 'pobj',
#    'lemma_': 'OMR',
#    '_': {}},
#   {'text': '.',
#    'idx': 4701,
#    'tag_': '.',
#    'pos_': 'PUNCT',
#    'dep_': 'punct',
#    'lemma_': '.',
#    '_': {}},
#   {'text': '\n',
#    'idx': 4702,
#    'tag_': '_SP',
#    'pos_': 'SPACE',
#    'dep_': 'ROOT',
#    'lemma_': '\n',
#    '_': {}},
#   {'text': 'Indication',
#    'idx': 4703,
#    'tag_': 'NN',
#    'pos_': 'NOUN',
#    'dep_': 'ROOT',
#    'lemma_': 'indication',
#    '_': {}},
#   ...],
#  'tags': ['O',
#   'U-OCCURRENCE',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'U-OCCURRENCE',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PROBLEM',
#   'I-PROBLEM',
#   'L-PROBLEM',
#   'O',
#   'U-PROBLEM',
#   'O',
#   'U-PROBLEM',
#   'O',
#   'U-PROBLEM',
#   'O',
#   'U-TREATMENT',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'U-OCCURRENCE',
#   'O',
#   'B-CLINICAL_DEPT',
#   'L-CLINICAL_DEPT',
#   'O',
#   'B-PROBLEM',
#   'L-PROBLEM',
#   'O',
#   'O',
#   'B-CLINICAL_DEPT',
#   'L-CLINICAL_DEPT',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-CLINICAL_DEPT',
#   'L-CLINICAL_DEPT',
#   'O',
#   'B-PROBLEM',
#   'I-PROBLEM',
#   'L-PROBLEM',
#   'O',
#   'U-PROBLEM',
#   'O',
#   'B-PROBLEM',
#   'L-PROBLEM',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'U-PROBLEM',
#   'O',
#   'O',
#   'O',
#   'U-TEST',
#   'O',
#   'O',
#   'U-TEST',
#   'O',
#   'O',
#   'U-TEST',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'U-PROBLEM',
#   'O',
#   'B-PROBLEM',
#   'I-PROBLEM',
#   'L-PROBLEM',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'U-PROBLEM',
#   'O',
#   'O',
#   'O',
#   'O',
#   'U-PROBLEM',
#   'O',
#   'O',
#   'B-PROBLEM',
#   'I-PROBLEM',
#   'L-PROBLEM',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'U-TREATMENT',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'U-TREATMENT',
#   'O',
#   'O',
#   'O',
#   'O',
#   'U-TREATMENT',
#   'O',
#   'U-TREATMENT',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'U-TREATMENT',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-OCCURRENCE',
#   'L-OCCURRENCE',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'U-TREATMENT',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-TREATMENT',
#   'L-TREATMENT',
#   'O',
#   'U-TEST',
#   'U-OCCURRENCE',
#   'O',
#   'O',
#   'O',
#   'O',
#   'U-OCCURRENCE',
#   'O',
#   'B-CLINICAL_DEPT',
#   'L-CLINICAL_DEPT',
#   'O',
#   'B-TREATMENT',
#   'L-TREATMENT',
#   'O',
#   'O',
#   'B-TREATMENT',
#   'L-TREATMENT',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'U-OCCURRENCE',
#   'O',
#   'U-CLINICAL_DEPT',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PROBLEM',
#   'L-PROBLEM',
#   'O',
#   'B-OCCURRENCE',
#   'L-OCCURRENCE',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'U-TEST',
#   'O',
#   'O',
#   'O',
#   'B-PROBLEM',
#   'L-PROBLEM',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-TREATMENT',
#   'L-TREATMENT',
#   'O',
#   'O',
#   'O',
#   'U-PROBLEM',
#   'O',
#   'U-PROBLEM',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PROBLEM',
#   'I-PROBLEM',
#   'L-PROBLEM',
#   'O',
#   'O',
#   'O',
#   'O',
#   'U-PROBLEM',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'U-OCCURRENCE',
#   'O',
#   'O',
#   'B-OCCURRENCE',
#   'L-OCCURRENCE',
#   'O',
#   'B-TEST',
#   'L-TEST',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PROBLEM',
#   'L-PROBLEM',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'U-OCCURRENCE',
#   'O',
#   'U-TREATMENT',
#   'O',
#   'O',
#   'B-OCCURRENCE',
#   'L-OCCURRENCE',
#   'O',
#   'U-OCCURRENCE',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'U-OCCURRENCE',
#   'O',
#   'B-CLINICAL_DEPT',
#   'I-CLINICAL_DEPT',
#   'L-CLINICAL_DEPT',
#   'O',
#   'O',
#   'O',
#   'B-PROBLEM',
#   'L-PROBLEM',
#   'O',
#   'U-EVIDENTIAL',
#   'U-PROBLEM',
#   'O',
#   'B-PROBLEM',
#   'L-PROBLEM',
#   'O',
#   'O',
#   'O',
#   'U-OCCURRENCE',
#   'O',
#   'O',
#   'B-OCCURRENCE',
#   'I-OCCURRENCE',
#   'I-OCCURRENCE',
#   'I-OCCURRENCE',
#   'L-OCCURRENCE',
#   'O',
#   'U-OCCURRENCE',
#   'O',
#   'U-TEST',
#   'O',
#   'O',
#   'O',
#   'U-PROBLEM',
#   'O',
#   'O',
#   'O',
#   'U-EVIDENTIAL',
#   'U-PROBLEM',
#   'O',
#   'U-PROBLEM',
#   'O',
#   'U-PROBLEM',
#   'O',
#   'B-PROBLEM',
#   'L-PROBLEM',
#   'O',
#   'B-PROBLEM',
#   'L-PROBLEM',
#   'O',
#   'U-PROBLEM',
#   'O',
#   'O',
#   'B-PROBLEM',
#   'L-PROBLEM',
#   'O',
#   'O',
#   'O',
#   'B-CLINICAL_DEPT',
#   'I-CLINICAL_DEPT',
#   'L-CLINICAL_DEPT',
#   'O',
#   'O',
#   'U-PROBLEM',
#   'O',
#   'U-TEST',
#   'O',
#   'O',
#   'O',
#   'U-TREATMENT',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-TREATMENT',
#   'I-TREATMENT',
#   'I-TREATMENT',
#   'I-TREATMENT',
#   'L-TREATMENT',
#   'O',
#   'B-TEST',
#   'I-TEST',
#   'L-TEST',
#   'U-OCCURRENCE',
#   'O',
#   'U-TEST',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'U-PROBLEM',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-TEST',
#   'L-TEST',
#   'O',
#   'O',
#   'U-OCCURRENCE',
#   'O',
#   'B-TEST',
#   'L-TEST',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PROBLEM',
#   'I-PROBLEM',
#   'I-PROBLEM',
#   'L-PROBLEM',
#   'O',
#   'B-TEST',
#   'L-TEST',
#   'O',
#   'O',
#   'O',
#   'B-TEST',
#   'L-TEST',
#   'O',
#   'B-TREATMENT',
#   'I-TREATMENT',
#   'I-TREATMENT',
#   'L-TREATMENT',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PROBLEM',
#   'I-PROBLEM',
#   'I-PROBLEM',
#   'L-PROBLEM',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-TREATMENT',
#   'I-TREATMENT',
#   'I-TREATMENT',
#   'L-TREATMENT',
#   'O',
#   'O',
#   'O',
#   'U-PROBLEM',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-TEST',
#   'I-TEST',
#   'L-TEST',
#   'B-OCCURRENCE',
#   'L-OCCURRENCE',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-TREATMENT',
#   'I-TREATMENT',
#   'I-TREATMENT',
#   'I-TREATMENT',
#   'L-TREATMENT',
#   'O',
#   'O',
#   'B-CLINICAL_DEPT',
#   'I-CLINICAL_DEPT',
#   'L-CLINICAL_DEPT',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'U-TREATMENT',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-CLINICAL_DEPT',
#   'I-CLINICAL_DEPT',
#   'L-CLINICAL_DEPT',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'U-PROBLEM',
#   'O',
#   'O',
#   'B-TREATMENT',
#   'I-TREATMENT',
#   'I-TREATMENT',
#   'I-TREATMENT',
#   'I-TREATMENT',
#   'L-TREATMENT',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-CLINICAL_DEPT',
#   'L-CLINICAL_DEPT',
#   'O',
#   'O',
#   'U-TEST',
#   'O',
#   'B-TEST',
#   'L-TEST',
#   'O',
#   'O',
#   'O',
#   'U-OCCURRENCE',
#   'O',
#   'O',
#   'B-TEST',
#   'I-TEST',
#   'L-TEST',
#   'O',
#   'O',
#   'O',
#   'O',
#   'U-PROBLEM',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'U-PROBLEM',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-TREATMENT',
#   'I-TREATMENT',
#   'I-TREATMENT',
#   'L-TREATMENT',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'U-TREATMENT',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-TEST',
#   'L-TEST',
#   'O',
#   'O',
#   'O',
#   'B-PROBLEM',
#   'I-PROBLEM',
#   'I-PROBLEM',
#   'I-PROBLEM',
#   'L-PROBLEM',
#   'O',
#   'O',
#   'B-TEST',
#   'L-TEST',
#   'O',
#   'B-TEST',
#   'L-TEST',
#   'O',
#   'O',
#   'O',
#   'U-TREATMENT',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-CLINICAL_DEPT',
#   'I-CLINICAL_DEPT',
#   'L-CLINICAL_DEPT',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'U-OCCURRENCE',
#   'O',
#   'B-CLINICAL_DEPT',
#   'L-CLINICAL_DEPT',
#   'O',
#   'B-OCCURRENCE',
#   'I-OCCURRENCE',
#   'L-OCCURRENCE',
#   'O',
#   'B-PROBLEM',
#   'L-PROBLEM',
#   'O',
#   'O',
#   'O',
#   'B-PROBLEM',
#   'L-PROBLEM',
#   'O',
#   'O',
#   'O',
#   'U-OCCURRENCE',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'U-TREATMENT',
#   'O',
#   'O',
#   'U-PROBLEM',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PROBLEM',
#   'I-PROBLEM',
#   'I-PROBLEM',
#   'L-PROBLEM',
#   'O',
#   'O',
#   'O',
#   'B-PROBLEM',
#   'I-PROBLEM',
#   'L-PROBLEM',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PROBLEM',
#   'L-PROBLEM',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PROBLEM',
#   'I-PROBLEM',
#   'I-PROBLEM',
#   'L-PROBLEM',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-TREATMENT',
#   'L-TREATMENT',
#   'O',
#   'B-CLINICAL_DEPT',
#   'L-CLINICAL_DEPT',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-TEST',
#   'L-TEST',
#   'B-PROBLEM',
#   'L-PROBLEM',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PROBLEM',
#   'L-PROBLEM',
#   'O',
#   'O',
#   'O',
#   'B-PROBLEM',
#   'L-PROBLEM',
#   'O',
#   'U-TEST',
#   'O',
#   'U-TEST',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'U-OCCURRENCE',
#   'O',
#   'B-CLINICAL_DEPT',
#   'L-CLINICAL_DEPT',
#   'O',
#   'O',
#   'B-PROBLEM',
#   'I-PROBLEM',
#   'I-PROBLEM',
#   'L-PROBLEM',
#   'O',
#   'O',
#   'O',
#   'U-OCCURRENCE',
#   'O',
#   'B-CLINICAL_DEPT',
#   'I-CLINICAL_DEPT',
#   'L-CLINICAL_DEPT',
#   'O',
#   'O',
#   'B-TEST',
#   'I-TEST',
#   'L-TEST',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'U-TREATMENT',
#   'O',
#   'U-PROBLEM',
#   'O',
#   'U-TREATMENT',
#   'O',
#   'O',
#   'O',
#   'B-TREATMENT',
#   'I-TREATMENT',
#   'I-TREATMENT',
#   'L-TREATMENT',
#   'O',
#   'U-TREATMENT',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'U-OCCURRENCE',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'U-PROBLEM',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PROBLEM',
#   'I-PROBLEM',
#   'L-PROBLEM',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'U-TREATMENT',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PROBLEM',
#   'I-PROBLEM',
#   'L-PROBLEM',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'U-TEST',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'U-PROBLEM',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PROBLEM',
#   'I-PROBLEM',
#   'L-PROBLEM',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-TREATMENT',
#   'I-TREATMENT',
#   'L-TREATMENT',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'U-TREATMENT',
#   'O',
#   'U-TREATMENT',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-TREATMENT',
#   'L-TREATMENT',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'U-TREATMENT',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'U-TREATMENT',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   ...],
#  'template_id': None,
#  'metadata': None}
